# %%
import pandas as pd
df = pd.read_csv('clean_dataset.csv')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import pandas as pd
#       2 df = pd.read_csv('clean_dataset.csv')
#
# ModuleNotFoundError: No module named 'pandas'
