# %% [markdown]
# ## 🌟 Exercice 1 : Réflexion sur les niveaux Open Source
#
# ### 1. Rassembler les définitions
#
# **Entièrement ouvert** :
#
# _Votre définition ici_
#
# **Poids libérés** :
#
# _Votre définition ici_
#
# **Architecture uniquement** :
#
# _Votre définition ici_

# %% [markdown]
# ### 2. Identifier les caractéristiques clés & 3. Comparez-les côte à côte
#
# | Qu'est-ce qui est ouvert ? | Impact sur la reconversion/modification |
# |:---------------------------|:----------------------------------------|
# | Entièrement ouvert         | Vous pouvez inspecter, modifier et recycler l’ensemble du modèle. |
# | Poids libérés              | Vous disposez des poids nécessaires pour affiner le code, mais pas pour le code complet. |
# | Architecture uniquement    | Vous connaissez la structure mais manquez de poids pré-entraînés. |
#
# _Ajoutez vos propres notes de caractéristiques clés ci-dessous, si désiré._

# %% [markdown]
# ### 4. Rédigez votre paragraphe comparatif
#
# _Écrivez votre paragraphe comparatif de 3 à 5 phrases ici, définissant chaque niveau d'ouverture avec vos propres mots et mettant en évidence un avantage ou une limitation principale de chacun._

# %% [markdown]
# ### 5. Répondez à la question des soins de santé
#
# _Réfléchissez à la création d’un assistant spécifique aux soins de santé qui doit être recyclé sur la base de données cliniques. Écrivez 1 à 2 phrases expliquant quel niveau d’ouverture est essentiel pour cette tâche et pourquoi ce niveau prend en charge le réglage fin spécifique au domaine._

# %% [markdown]
# ---

# %% [markdown]
# ## 🌟 Exercice 2 : Vérification des licences pour l'utilisation du SaaS
#
# ### 1. Sélectionnez vos modèles
#
# *   **Modèle 1 URL :** [Collez l'URL de votre premier modèle Hugging Face ici, par exemple: `https://huggingface.co/mistralai/Mistral-7B-Instruct`](https://huggingface.co/mistralai/Mistral-7B-Instruct)
# *   **Modèle 2 URL :** [Collez l'URL de votre deuxième modèle Hugging Face ici, par exemple: `https://huggingface.co/meta-llama/Llama-2-7b-chat-hf`](https://huggingface.co/meta-llama/Llama-2-7b-chat-hf)
#
# ### 5. Build Your Checklist
#
# ```markdown
# - [ ] **Modèle 1 Nom (ex: mistralai/Mistral-7B-Instruct)**
#   - Type de licence:
#     - [ ] Nom de la licence (ex: Apache 2.0)
#   - Utilisation commerciale autorisée:
#     - [ ] Oui / Non / Conditionnel (avec une brève note sur les conditions, ex: "autorisé avec attribution")
#   - Restrictions:
#     - [ ] Restriction #1 (ex: Limite de 10k utilisateurs/mois)
#     - [ ] Restriction #2 (ex: Exigences d'attribution)
#     - [ ] Restriction #3 (ex: Contrôles à l'exportation)
#
# - [ ] **Modèle 2 Nom (ex: meta-llama/Llama-2-7b-chat-hf)**
#   - Type de licence:
#     - [ ] Nom de la licence (ex: Llama 2 Community License)
#   - Utilisation commerciale autorisée:
#     - [ ] Oui / Non / Conditionnel (avec une brève note sur les conditions, ex: "autorisé avec attribution et pour moins de X utilisateurs")
#   - Restrictions:
#     - [ ] Restriction #1 (ex: Limite d'utilisateurs mensuels)
#     - [ ] Restriction #2 (ex: Exigences d'attribution)
#     - [ ] Restriction #3 (ex: Pas de revente)
# ```
#
# _Remplissez les cases à cocher et les détails pour chaque modèle directement dans le bloc de code Markdown ci-dessus._

# %% [markdown]
# ---

# %% [markdown]
# ## 🌟 Exercice 3 : Défi Matchmaker LLM
#
# ### 1. Search Filter Summary
#
# **LegalTech**
# *   **Filtres/URL utilisés :** _(Ex: "logic", "CPU compatible", "<=7B params") [Collez l'URL de recherche Hugging Face ici]_
#
# **EdTech**
# *   **Filtres/URL utilisés :** _(Ex: "math", "logic", "low-end laptop", "<=7B params") [Collez l'URL de recherche Hugging Face ici]_
#
# **ONG mondiale**
# *   **Filtres/URL utilisés :** _(Ex: "multilingual", ">=5 languages", "CPU compatible", "<=7B params") [Collez l'URL de recherche Hugging Face ici]_
#
# ### 2. Filled Table
#
# | Team          | Needs                                                      | Your Pick                                                                   |
# |:--------------|:-----------------------------------------------------------|:----------------------------------------------------------------------------|
# | LegalTech     | Modèle rapide pour chatbot à forte logique sur CPU         | [Votre modèle choisi] (par exemple, `mistralai/Mistral-7B-Instruct`)        |
# | EdTech        | LLM axé sur la logique et les mathématiques sur les ordinateurs portables bas de gamme | [Votre modèle choisi]                                                       |
# | ONG mondiale  | Modèle qui parle bien 5+ langues                           | [Votre modèle choisi]                                                       |
#
# _Remplissez la colonne "Your Pick" pour chaque équipe avec le modèle que vous avez sélectionné et, éventuellement, une note entre parenthèses justifiant votre choix._

# %% [markdown]
# ---

# %% [markdown]
# ## 🌟 Exercice 4 : Audit de préparation locale
#
# ### 1. & 2. Rassemblez les spécifications de votre système et Préparez la table d'audit
#
# ```markdown
# | Requirement               | Your System Specs   | Meets Requirement? |
# |:--------------------------|:--------------------|:-------------------|
# | RAM (≥ 16 GB)             | _(Ex: 8 GB)_        | ✅ / ❌            |
# | Free Disk Space (≥ 40 GB) | _(Ex: 75 GB)_       | ✅ / ❌            |
# | OS (Linux/WSL2)           | _(Ex: Windows 10)_  | ✅ / ❌            |
# ```
#
# ### 3. & 4. Vérifier par rapport aux exigences et Évaluer la préparation de lama.cpp
#
# _Notes sur la compatibilité de votre processeur (AVX, SSE) et les outils de compilation (gcc/clang, make, cmake) :_
#
# _Votre réponse ici._
#
# ### 5. Identifier les besoins de mise à niveau
#
# _Résumé des mises à niveau nécessaires pour exécuter un modèle quantifié 7B localement :_
#
# _Votre réponse ici._

# %% [markdown]
# ---

# %% [markdown]
# ## 🌟 Exercice 5 : Benchmark-Based Model Explorer
#
# ### 6. Remplissez le tableau comparatif
#
# | Nom du modèle               | Score de HellaSwag | Score MMLU | Type de licence | Cas d'utilisation idéal |
# |:----------------------------|:-------------------|:-----------|:----------------|:------------------------|
# | organization/model-name-A   | _(Ex: 85,2)_       | _(Ex: 54.3)_ | _(Ex: Apache 2.0)_ | _(Ex: Agent de questions-réponses Commonsense)_ |
# | organization/model-name-B   | _(Ex: 72,4)_       | _(Ex: 62.1)_ | _(Ex: MIT)_     | _(Ex: Tuteur de questions académiques)_ |
# | organization/model-name-C   | _(Ex: 80,0)_       | _(Ex: 58,7)_ | _(Ex: CC PAR 4,0)_ | _(Ex: Assistante multilingue)_ |
#
# _Remarque: Remplissez ce tableau en utilisant l'Open LLM Leaderboard de Hugging Face._
#
# ### Réflexion (facultatif)
#
# _Un paragraphe expliquant pourquoi les repères – et non le battage médiatique – devraient guider le choix du modèle :_
#
# _Votre réflexion ici._

# %% [markdown]
# ---

# %% [markdown]
# ## 🌟 Exercice 6 : Cloud vs. Plan de déploiement local
#
# ### 3. Draft Your 5-Bullet List
#
# **Déploiement local**
# *   ✔️ _(Avantage 1, ex: Faible latence)_
# *   ❌ _(Inconvénient 1, ex: Coût matériel initial élevé)_
# *   ✔️ _(Avantage 2, ex: Aucune interruption à froid)_
# *   ❌ _(Inconvénient 2, ex: Évolutivité limitée)_
# *   ✔️ _(Avantage 3, ex: Contrôle total des données)_
#
# **Déploiement Cloud**
# *   ✔️ _(Avantage 1, ex: Accès facile aux GPU)_
# *   ❌ _(Inconvénient 1, ex: Dépendance au fournisseur)_
# *   ✔️ _(Avantage 2, ex: Haute évolutivité)_
# *   ❌ _(Inconvénient 2, ex: Problèmes de latence potentiels)_
# *   ✔️ _(Avantage 3, ex: Moins de maintenance matérielle)_
#
# ### 4. (Facultatif) Exécuter un modèle 7B sur Colab

# %%
# !pip install transformers accelerate

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
import time

model_name = "meta-llama/Llama-2-7b-chat-hf"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name, device_map="auto", torch_dtype="auto")

inputs = tokenizer("Hello, world!", return_tensors="pt").to(model.device)
start = time.time()
outputs = model.generate(**inputs, max_new_tokens=50)
print(tokenizer.decode(outputs[0]))
print("Elapsed:", time.time() - start, "seconds")

# %% [markdown]
# ### 5. Finalize Your Plan
#
# _Quel modèle avez-vous essayé et combien de secondes cela a-t-il pris pour répondre ?_
#
# _Votre réponse ici._
